# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilkushwaha7777/matplotpractice/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x =[1, 2, 3, 5]
y= [5, 6,7,8]
plt.plot(x, y)
plt.show()

# %%
x =[1, 2, 3, 5]
y= [5, 6,7,8]
c = "r"
plt.plot(x, y, c)
plt.show()

# %%
x = [5, 23, 67, 86, 43]
y = [23, 55, 8, 34, 65]
plt.plot(x, y, marker = "o")
plt.show()

# %%
x = [12,13,8,5,3]
y = [19,12,15,12,42]
plt.plot(x,y)
plt.plot(y, marker = ">")
plt.plot(x, marker = "o")
plt.show()

# %% [markdown]
# # bar graph

# %%
x =[1, 2, 3, 4]
y= [5, 6,7,8]

plt.bar(x,y)
plt.show()

# %%
x =[1, 2, 3, 4]
y= [5, 6,7,8]
c=["r","g","b","y"]
plt.bar(x,y,color = c)
plt.show()

# %%
import numpy as np
x= np.array(["A",'B','C','D'])
Y = np.array([1,3,4,5])
plt.barh(x,y)
plt.show()

# %%
x= np.array(["A",'B','C','D'])
Y = np.array([1,3,4,5])
plt.barh(x,y, color = "red")
plt.show()

# %%
x= np.array(["A",'B','C','D'])
Y = np.array([1,3,4,5])
plt.bar(x,y, color = "pink", width = 0.2)
plt.show()

# %%
x= np.array(["A",'B','C','D'])
Y = np.array([1,3,4,5])
plt.barh(x,y, color = "green", height = 0.5)
plt.show()

# %% [markdown]
# #scatter plot

# %%
x = [1,2,3,4,5,6,7]
y = [4,2,3,5,6,7,8]
plt.title("scatter plot")
plt.xlabel("math")
plt.ylabel("science")
plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6,7]
y = [4,2,3,5,6,7,8]
plt.title("red color")
plt.xlabel("number")
plt.ylabel("month")
c = ["red", "blue", "green", "yellow", "pink", "orange", "magenta"]
plt.scatter(x,y, color = c)
plt.show()

# %%
x = [1,2,3,4,5,6,7]
y = [4,2,3,5,6,7,8]
plt.title("red color")
plt.xlabel("number")
plt.ylabel("month")
plt.scatter(x,y, color = "r")
plt.show()

# %%
x = [1,2,3,4,5,6,7]
y = [4,2,3,5,6,7,8]
plt.title("red color")
plt.xlabel("number")
plt.ylabel("month")
c = ["red", "blue", "green", "yellow", "pink", "orange", "magenta"]
plt.scatter(x,y, color = c, s= 1000)
plt.show()

# %% [markdown]
# #working on image just for fun

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname = r"parrot.jpeg"

#opening image using pil

image = Image.open(fname).convert("L")

#mapping image to gray scale

plt.imshow(image, cmap = 'gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname = r"parrot.jpeg"

#opening image using pil

image = Image.open(fname).convert("L")

#mapping image to gray scale

plt.imshow(image, cmap = 'RdYlBu')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname = r"parrot.jpeg"

#opening image using pil

image = Image.open(fname).convert("L")

#mapping image to gray scale

plt.imshow(image, cmap = 'PuBu_r')
plt.title("parrot")
plt.xlabel("width")
plt.ylabel("height")
plt.grid()
plt.show()

# %% [markdown]
# #matplotlib - pie
